# %% [markdown]
# # Coding a Game in Python!

# %% [markdown]
# ## Part 1 - Setting Up the Environment

# %% [markdown]
# ### 1. Overview

# %% [markdown]
# ![image.png](attachment:86ed7420-7a22-44d1-9c61-50a1d29944d8.png)!

# %% [markdown]
# ### 2. Install Interpreter

# %% [markdown]
# ### 3. Install Python

# %% [markdown]
# ### 4. Install Relevant Packages/Modules
